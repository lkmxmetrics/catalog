# %%
# Import the dependencies
import requests
import pandas as pd
from bs4 import BeautifulSoup
## set up base url 
base_url = 'https://www.mtggoldfish.com/index/{}#paper'
res = requests.get(base_url.format('DOM'))
soup = BeautifulSoup(res.text, 'lxml')
## strats
full_list = []
for row in soup.select('tr'):
  cols = row.findAll('td')
  cols = [element.text.strip() for element in cols]
  for col in cols:
    full_list.append(col)
# separate columns
K = 8 

parse_list = []
for i in range(0,K):
  parse_list.append(full_list[i::K])

## isolate the columns 
card_name = parse_list[0][1:]
card_set = parse_list[1][1:]
card_rarity = parse_list[2][1:]
card_price = parse_list[3][1:]

# both lists, with columns specified
df = pd.DataFrame(list(zip(
        card_name, 
        card_set,
        card_rarity,
        card_price)),
    columns =[
        'Name', 
        'Set',
        'Rarity',
        'Price'])

df.to_csv(r'domscrape.csv',index=False, header=True)

df
# Out:
#                           Name  Set  Rarity  Price
# 0                    Mox Amber  DOM  Mythic  40.00
# 1    Teferi, Hero of Dominaria  DOM  Mythic  25.00
# 2             Helm of the Host  DOM    Rare  18.52
# 3             Lyra Dawnbringer  DOM  Mythic  11.15
# 4          Karn, Scion of Urza  DOM  Mythic   8.40
# ..                         ...  ...     ...    ...
# 552       Urza's Ruinous Blast  DOM    Rare   0.02
# 553              Verdant Force  DOM    Rare   0.02
# 554               Weatherlight  DOM  Mythic   0.02
# 555   Yawgmoth's Vile Offering  DOM    Rare   0.02
# 556   Zahid, Djinn of the Lamp  DOM    Rare   0.02
#
# [557 rows x 4 columns]

# %%
df
# Out:
#   Name  Score
# 0    a     90
# 1    b     80
# 2    c     95
# 3    d     20

# %%
card_name = parse_list[0][1:]
card_set = parse_list[1]
card_rarity = parse_list[2]
card_price = parse_list[3]

# %%
card_name
# Out:
# ['Mox Amber',
#  'Teferi, Hero of Dominaria',
#  'Helm of the Host',
#  'Lyra Dawnbringer',
#  'Karn, Scion of Urza',
#  'Hinterland Harbor',
#  'Clifftop Retreat',
#  'Muldrotha, the Gravetide',
#  'Woodland Cemetery',
#  'Isolated Chapel',
#  'Cabal Stronghold',
#  'Shalai, Voice of Plenty',
#  'Sulfur Falls',
#  'Gilded Lotus',
#  'Phyrexian Scriptures',
#  'Tatyova, Benthic Druid',
#  'Rat Colony',
#  'Jhoira, Weatherlight Captain',
#  "Karn's Temporal Sundering",
#  'Damping Sphere',
#  'Naru Meha, Master Wizard',
#  'Demonlord Belzenlok',
#  "Multani, Yavimaya's Avatar",
#  'Tetsuko Umezawa, Fugitive',
#  'History of Benalia',
#  'Steel Leaf Champion',
#  "Primevals' Glorious Rebirth",
#  'Jaya Ballard',
#  'Oath of Teferi',
#  'Darigaaz Reincarnated',
#  'Final Parting',
#  'Marwyn, the Nurturer',
#  'Verix Bladewing',
#  "Urza's Ruinous Blast",
#  'Squee, the Immortal',
#  'Blackblade Reforged',
#  'Josu Vess, Lich Knight',
#  'Jodah, Archmage Eternal',
#  'Weatherlight',
#  'Merfolk Trickster',
#  'Siege-Gang Commander',
#  'Sylvan Awakening',
#  'Thran Temporal Gateway',
#  'Goblin Chainwhirler',
#  'Song of Freyalise',
#  'Benalish Marshal',
#  'Grand Warlord Radha',
#  "Kamahl's Druidic Vow",
#  "Forebear's Blade",
#  'Goblin Warchief',
#  "Teshar, Ancestor's Apostle",
#  'Unwind',
#  'Tempest Djinn',
#  'Traxos, Scourge of Kroog',
#  'Naban, Dean of Iteration',
#  'Grow from the Ashes',
#  'Baird, Steward of Argive',
#  "Yawgmoth's Vile Offering",
#  'Aryel, Knight of Windgrace',
#  "Lich's Mastery",
#  'Territorial Allosaurus',
#  'The Antiquities War',
#  'The Mirari Conjecture',
#  'Verdant Force',
#  'Fall of the Thran',
#  "Jaya's Immolating Inferno",
#  "Jhoira's Familiar",
#  'Precognition Field',
#  'The Mending of Dominaria',
#  'Danitha Capashen, Paragon',
#  'The Eldest Reborn',
#  'Torgaar, Famine Incarnate',
#  'Whisper, Blood Liturgist',
#  'Rite of Belzenlok',
#  "Curator's Ward",
#  "Mishra's Self-Replicator",
#  'Dread Shade',
#  'Broken Bond',
#  "Wizard's Retort",
#  'Cast Down',
#  "Chandra's Outburst",
#  'Niambi, Faithful Healer',
#  'Two-Headed Giant',
#  "Gaea's Blessing",
#  'Evra, Halcyon Witness',
#  'Sporecrown Thallid',
#  'Dauntless Bodyguard',
#  'Kazarov, Sengir Pureblood',
#  'Llanowar Elves',
#  'The First Eruption',
#  'Zahid, Djinn of the Lamp',
#  'Zhalfirin Void',
#  'Daring Archaeologist',
#  'Slimefoot, the Stowaway',
#  "Wizard's Lightning",
#  'Haphazard Bombardment',
#  'Seal Away',
#  'Knight of Malice',
#  'Llanowar Scout',
#  'Skirk Prospector',
#  'Adeliz, the Cinder Wind',
#  'Arvad the Cursed',
#  'Fungal Plots',
#  "Raff Capashen, Ship's Mage",
#  "Shanna, Sisay's Legacy",
#  'Spore Swarm',
#  'The Flame of Keld',
#  'Amaranthine Wall',
#  'Settle the Score',
#  'Valduk, Keeper of the Flame',
#  'Knight of Grace',
#  'Mountain262',
#  'Blink of an Eye',
#  'Island254',
#  'Island257',
#  "On Serra's Wings",
#  'Swamp258',
#  "Artificer's Assistant",
#  'Board the Weatherlight',
#  "Chainer's Torment",
#  'Champion of the Flame',
#  'Demonic Vigor',
#  'Diligent Excavator',
#  'Elfhame Druid',
#  'Fight with Fire',
#  'Firefist Adept',
#  'Forest266',
#  'Forest267',
#  'Forest268',
#  'Forest269',
#  'Garna, the Bloodflame',
#  'Ghitu Lavarunner',
#  'Goblin Barrage',
#  'Grunn, the Lonely King',
#  'Hallar, the Firefletcher',
#  'Howling Golem',
#  'Icy Manipulator',
#  "In Bolas's Clutches",
#  'Island255',
#  'Island256',
#  'Juggernaut',
#  'Karplusan Hound',
#  'Kwende, Pride of Femeref',
#  'Lingering Phantom',
#  'Meandering River',
#  'Memorial to Folly',
#  'Memorial to Genius',
#  'Memorial to Glory',
#  'Memorial to Unity',
#  'Memorial to War',
#  'Mountain265',
#  "Nature's Spiral",
#  'Opt',
#  'Orcish Vandal',
#  'Plains251',
#  'Plains252',
#  'Plains253',
#  'Powerstone Shard',
#  'Pyromantic Pilgrim',
#  'Rona, Disciple of Gix',
#  'Sage of Lat-Nam',
#  'Sanctum Spirit',
#  'Saproling Migration',
#  'Sentinel of the Pearl Trident',
#  'Serra Angel',
#  'Shield of the Realm',
#  'Skizzik',
#  'Slinn Voda, the Rising Deep',
#  "Sorcerer's Wand",
#  'Swamp259',
#  'Swamp260',
#  'Syncopate',
#  "Teferi's Sentinel",
#  'Temporal Machinations',
#  'Thallid Soothsayer',
#  'Thorn Elemental',
#  "Tiana, Ship's Caretaker",
#  'Time of Ice',
#  'Triumph of Gerrard',
#  'Untamed Kavu',
#  'Urgoros, the Empty One',
#  "Urza's Tome",
#  'Warcry Phoenix',
#  "Warlord's Fury",
#  'Weight of Memory',
#  'Wild Onslaught',
#  'Yargle, Glutton of Urborg',
#  'Adventurous Impulse',
#  'Mountain263',
#  'Plains250',
#  'Timber Gorge',
#  'Voltaic Servant',
#  'Yavimaya Sapherd',
#  'Divest',
#  'Fungal Infection',
#  'Thallid Omnivore',
#  'Adamant Will',
#  'Dark Bargain',
#  'Skittering Surveyor',
#  'Deep Freeze',
#  'Sparring Construct',
#  'Vicious Offering',
#  'Academy Drake',
#  'Academy Journeymage',
#  'Ancient Animus',
#  'Arbor Armament',
#  'Arcane Flight',
#  'Baloth Gorger',
#  'Benalish Honor Guard',
#  'Blessed Light',
#  'Blessing of Belzenlok',
#  'Bloodstone Goblin',
#  'Bloodtallow Candle',
#  'Cabal Paladin',
#  'Caligo Skin-Witch',
#  'Call the Cavalry',
#  'Charge',
#  'Cloudreader Sphinx',
#  'Cold-Water Snapper',
#  'Corrosive Ooze',
#  'Deathbloom Thallid',
#  'Divination',
#  'Feral Abomination',
#  'Fervent Strike',
#  'Frenzied Rage',
#  'Ghitu Journeymage',
#  "Gideon's Reproach",
#  'Gift of Growth',
#  'Healing Grace',
#  'Homarid Explorer',
#  'Invoke the Divine',
#  'Jousting Lance',
#  'Keldon Overseer',
#  'Krosan Druid',
#  'Mesa Unicorn',
#  'Mountain264',
#  "Navigator's Compass",
#  'Primordial Wurm',
#  'Radiating Lightning',
#  'Rescue',
#  'Run Amok',
#  'Shivan Fire',
#  'Short Sword',
#  'Swamp261',
#  'Tragic Poet',
#  'Befuddle',
#  'Cabal Evangel',
#  "D'Avenant Trapper",
#  'Drudge Sentinel',
#  'Dub',
#  'Eviscerate',
#  'Ghitu Chronicler',
#  'Guardians of Koilos',
#  'Keldon Raider',
#  'Keldon Warcaller',
#  'Llanowar Envoy',
#  'Mammoth Spider',
#  'Rampaging Cyclops',
#  'Relic Runner',
#  'Seismic Shift',
#  'Sergeant-at-Arms',
#  'Serra Disciple',
#  'Soul Salvage',
#  'Stronghold Confessor',
#  'Tolarian Scholar',
#  'Vodalian Arcanist',
#  'Windgrace Acolyte',
#  'Aesthir Glider',
#  'Aven Sentry',
#  'Excavation Elephant',
#  'Fiery Intervention',
#  'Fire Elemental',
#  "Gaea's Protector",
#  'Knight of New Benalia',
#  'Pardic Wanderer',
#  'Pegasus Courser',
#  'Pierce the Sky',
#  'Firesong and Sunspeaker',
#  'Teferi, Hero of Dominaria',
#  'Mox Amber',
#  "Chandra's Outburst",
#  'Pyromantic Pilgrim',
#  'Karn, Scion of Urza',
#  'Karplusan Hound',
#  'Timber Gorge',
#  'Chandra, Bold Pyromancer',
#  'Niambi, Faithful Healer',
#  'Temporal Machinations',
#  "Teferi's Sentinel",
#  'Meandering River',
#  'Teferi, Timebender',
#  'Steel Leaf Champion',
#  'Cast Down',
#  'History of Benalia',
#  'Lyra Dawnbringer',
#  'Goblin Chainwhirler',
#  'Damping Sphere',
#  'Isolated Chapel',
#  'Sulfur Falls',
#  'Academy Drake',
#  'Academy Journeymage',
#  'Bloodstone Goblin',
#  'Cloudreader Sphinx',
#  'Dark Bargain',
#  'Deathbloom Thallid',
#  'Deep Freeze',
#  'Divination',
#  'Drudge Sentinel',
#  'Dub',
#  'Eviscerate',
#  'Excavation Elephant',
#  'Feral Abomination',
#  'Firefist Adept',
#  'Ghitu Journeymage',
#  "Gideon's Reproach",
#  'Invoke the Divine',
#  'Island255',
#  'Juggernaut',
#  'Knight of New Benalia',
#  'Lingering Phantom',
#  "Nature's Spiral",
#  'Orcish Vandal',
#  'Pegasus Courser',
#  'Pierce the Sky',
#  'Plains252',
#  'Primordial Wurm',
#  'Relic Runner',
#  'Sanctum Spirit',
#  'Sentinel of the Pearl Trident',
#  'Sergeant-at-Arms',
#  'Short Sword',
#  'Stronghold Confessor',
#  'Swamp259',
#  'Swamp261',
#  'Thallid Omnivore',
#  'Thorn Elemental',
#  'Vodalian Arcanist',
#  'Warcry Phoenix',
#  'Wild Onslaught',
#  'Windgrace Acolyte',
#  'Aven Sentry',
#  'Befuddle',
#  'Benalish Honor Guard',
#  'Bloodtallow Candle',
#  'Cabal Paladin',
#  "Chainer's Torment",
#  'Charge',
#  'Demonic Vigor',
#  'Fervent Strike',
#  'Fiery Intervention',
#  'Forest267',
#  'Frenzied Rage',
#  'Ghitu Lavarunner',
#  'Gift of Growth',
#  'Healing Grace',
#  'Island254',
#  'Island256',
#  'Island257',
#  'Jousting Lance',
#  'Keldon Overseer',
#  'Keldon Warcaller',
#  'Kwende, Pride of Femeref',
#  'Memorial to Glory',
#  'Mesa Unicorn',
#  'Mountain262',
#  'Mountain263',
#  'Mountain265',
#  'Pardic Wanderer',
#  'Plains250',
#  'Plains253',
#  'Radiating Lightning',
#  'Rampaging Cyclops',
#  'Rona, Disciple of Gix',
#  'Run Amok',
#  'Serra Disciple',
#  'Shivan Fire',
#  'Swamp260',
#  'Tolarian Scholar',
#  'Untamed Kavu',
#  "Urza's Tome",
#  'Yavimaya Sapherd',
#  'Adamant Will',
#  'Adeliz, the Cinder Wind',
#  'Adventurous Impulse',
#  'Aesthir Glider',
#  'Amaranthine Wall',
#  'Ancient Animus',
#  'Arbor Armament',
#  'Arcane Flight',
#  "Artificer's Assistant",
#  'Arvad the Cursed',
#  'Baird, Steward of Argive',
#  'Baloth Gorger',
#  'Blessed Light',
#  'Blessing of Belzenlok',
#  'Blink of an Eye',
#  'Board the Weatherlight',
#  'Broken Bond',
#  'Cabal Evangel',
#  'Caligo Skin-Witch',
#  'Call the Cavalry',
#  'Champion of the Flame',
#  'Cold-Water Snapper',
#  'Corrosive Ooze',
#  "Curator's Ward",
#  "D'Avenant Trapper",
#  'Danitha Capashen, Paragon',
#  'Dauntless Bodyguard',
#  'Diligent Excavator',
#  'Divest',
#  'Elfhame Druid',
#  'Fight with Fire',
#  'Final Parting',
#  'Fire Elemental',
#  'Forest266',
#  'Forest268',
#  'Forest269',
#  'Fungal Infection',
#  'Fungal Plots',
#  "Gaea's Blessing",
#  "Gaea's Protector",
#  'Garna, the Bloodflame',
#  'Ghitu Chronicler',
#  'Goblin Barrage',
#  'Goblin Warchief',
#  'Grow from the Ashes',
#  'Grunn, the Lonely King',
#  'Guardians of Koilos',
#  'Hallar, the Firefletcher',
#  'Hinterland Harbor',
#  'Homarid Explorer',
#  'Howling Golem',
#  'Icy Manipulator',
#  "In Bolas's Clutches",
#  "Jhoira's Familiar",
#  'Keldon Raider',
#  'Knight of Grace',
#  'Knight of Malice',
#  'Krosan Druid',
#  'Llanowar Elves',
#  'Llanowar Envoy',
#  'Llanowar Scout',
#  'Mammoth Spider',
#  'Memorial to Folly',
#  'Memorial to Genius',
#  'Memorial to Unity',
#  'Memorial to War',
#  'Merfolk Trickster',
#  'Mountain264',
#  'Muldrotha, the Gravetide',
#  "Navigator's Compass",
#  "On Serra's Wings",
#  'Opt',
#  'Plains251',
#  'Powerstone Shard',
#  "Raff Capashen, Ship's Mage",
#  'Rat Colony',
#  'Rescue',
#  'Sage of Lat-Nam',
#  'Saproling Migration',
#  'Seal Away',
#  'Seismic Shift',
#  'Serra Angel',
#  'Settle the Score',
#  "Shanna, Sisay's Legacy",
#  'Shield of the Realm',
#  'Skirk Prospector',
#  'Skittering Surveyor',
#  'Skizzik',
#  'Slimefoot, the Stowaway',
#  'Slinn Voda, the Rising Deep',
#  'Song of Freyalise',
#  "Sorcerer's Wand",
#  'Soul Salvage',
#  'Sparring Construct',
#  'Spore Swarm',
#  'Sporecrown Thallid',
#  'Swamp258',
#  'Syncopate',
#  'Tatyova, Benthic Druid',
#  'Tetsuko Umezawa, Fugitive',
#  'Thallid Soothsayer',
#  'The Eldest Reborn',
#  'The Flame of Keld',
#  "Tiana, Ship's Caretaker",
#  'Time of Ice',
#  'Tragic Poet',
#  'Triumph of Gerrard',
#  'Unwind',
#  'Urgoros, the Empty One',
#  'Valduk, Keeper of the Flame',
#  'Vicious Offering',
#  'Voltaic Servant',
#  "Warlord's Fury",
#  'Weight of Memory',
#  'Whisper, Blood Liturgist',
#  "Wizard's Lightning",
#  "Wizard's Retort",
#  'Yargle, Glutton of Urborg',
#  'Zhalfirin Void',
#  'Aryel, Knight of Windgrace',
#  'Benalish Marshal',
#  'Blackblade Reforged',
#  'Cabal Stronghold',
#  'Clifftop Retreat',
#  'Darigaaz Reincarnated',
#  'Daring Archaeologist',
#  'Demonlord Belzenlok',
#  'Dread Shade',
#  'Evra, Halcyon Witness',
#  'Fall of the Thran',
#  "Forebear's Blade",
#  'Gilded Lotus',
#  'Grand Warlord Radha',
#  'Haphazard Bombardment',
#  'Helm of the Host',
#  'Jaya Ballard',
#  "Jaya's Immolating Inferno",
#  'Jhoira, Weatherlight Captain',
#  'Jodah, Archmage Eternal',
#  'Josu Vess, Lich Knight',
#  "Kamahl's Druidic Vow",
#  "Karn's Temporal Sundering",
#  'Kazarov, Sengir Pureblood',
#  "Lich's Mastery",
#  'Marwyn, the Nurturer',
#  "Mishra's Self-Replicator",
#  "Multani, Yavimaya's Avatar",
#  'Naban, Dean of Iteration',
#  'Naru Meha, Master Wizard',
#  'Oath of Teferi',
#  'Phyrexian Scriptures',
#  'Precognition Field',
#  "Primevals' Glorious Rebirth",
#  'Rite of Belzenlok',
#  'Shalai, Voice of Plenty',
#  'Siege-Gang Commander',
#  'Squee, the Immortal',
#  'Sylvan Awakening',
#  'Tempest Djinn',
#  'Territorial Allosaurus',
#  "Teshar, Ancestor's Apostle",
#  'The Antiquities War',
#  'The First Eruption',
#  'The Mending of Dominaria',
#  'The Mirari Conjecture',
#  'Thran Temporal Gateway',
#  'Torgaar, Famine Incarnate',
#  'Traxos, Scourge of Kroog',
#  'Two-Headed Giant',
#  "Urza's Ruinous Blast",
#  'Verdant Force',
#  'Verix Bladewing',
#  'Weatherlight',
#  'Woodland Cemetery',
#  "Yawgmoth's Vile Offering",
#  'Zahid, Djinn of the Lamp']

# %%
# import pandas as pd
import pandas as pd
  
card_name = parse_list[0][1:]
card_set = parse_list[1][1:]
card_rarity = parse_list[2][1:]
card_price = parse_list[3][1:]
  
# Calling DataFrame constructor after zipping
# both lists, with columns specified
df = pd.DataFrame(list(zip(card_name, card_set,card_rarity,card_price)),
               columns =['Name', 'Set','Rarity','Price'])
df
# Out:
#                           Name  Set  Rarity  Price
# 0                    Mox Amber  DOM  Mythic  35.86
# 1    Teferi, Hero of Dominaria  DOM  Mythic  27.00
# 2             Helm of the Host  DOM    Rare  16.49
# 3             Lyra Dawnbringer  DOM  Mythic  11.99
# 4          Karn, Scion of Urza  DOM  Mythic   8.38
# ..                         ...  ...     ...    ...
# 552            Verix Bladewing  DOM  Mythic   0.02
# 553               Weatherlight  DOM  Mythic   0.02
# 554          Woodland Cemetery  DOM    Rare   0.02
# 555   Yawgmoth's Vile Offering  DOM    Rare   0.02
# 556   Zahid, Djinn of the Lamp  DOM    Rare   0.02
#
# [557 rows x 4 columns]

# %%
df
# Out:
#                                              0
# Tabletop\n$ 265            PRICE CHANGE\n-0.72
# Mox Amber                                  DOM
# Teferi, Hero of Dominaria                  DOM
# Helm of the Host                           DOM
# Lyra Dawnbringer                           DOM
# ...                                        ...
# Verix Bladewing                            DOM
# Weatherlight                               DOM
# Woodland Cemetery                          DOM
# Yawgmoth's Vile Offering                   DOM
# Zahid, Djinn of the Lamp                   DOM
#
# [558 rows x 1 columns]

# %%
## strats??

# %%
# import pandas as pd
import pandas as pd
  
# list of strings
lst = ['Geeks', 'For', 'Geeks', 'is', 'portal', 'for', 'Geeks']
  
# list of int
lst2 = [11, 22, 33, 44, 55, 66, 77]
  
# Calling DataFrame constructor after zipping
# both lists, with columns specified
df = pd.DataFrame(list(zip(lst, lst2)),
               columns =['Name', 'val'])
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-6f339ecd8590> in <module>
# ----> 1 df = pd.DataFrame(list(zip(lst, lst2)),
#       2                columns =['Name', 'val'])
#
# NameError: name 'lst' is not defined

# %%
# importing pandas as pd 
import pandas as pd 
  
# list of name, degree, score
nme = ["aparna", "pankaj", "sudhir", "Geeku"]
deg = ["MBA", "BCA", "M.Tech", "MBA"]
scr = [90, 40, 80, 98]
  
# dictionary of lists 
dict = {'name': nme, 'degree': deg, 'score': scr} 
    
df = pd.DataFrame(dict)
    
df
# Out:
#      name  degree  score
# 0  aparna     MBA     90
# 1  pankaj     BCA     40
# 2  sudhir  M.Tech     80
# 3   Geeku     MBA     98

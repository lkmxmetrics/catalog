# %%
import pandas as pd

# %%
raw_csv_data = pd.read_csv('LMULLINS _ MTG INVENTORY 01_20 - Inventory.csv')

# %%
df = raw_csv_data.copy()
df = df.drop(['Unnamed: 6','Unnamed: 7'], axis = 1)

# %%
df
# Out:
#       Amount                     Card  Set  Rarity   Value    Total
# 0        3.0        Stoneforge Mystic  WWK    Rare  $55.66  $166.98
# 1        2.0            Breeding Pool  RNA    Rare  $22.99   $45.98
# 2        4.0              Aether Vial  IMA    Rare  $40.99  $163.96
# 3        4.0           Flooded Strand  KTK    Rare  $39.97  $159.88
# 4        2.0       Crucible of Worlds  M19  Mythic  $40.79   $81.58
# ...      ...                      ...  ...     ...     ...      ...
# 1130     NaN                      NaN  NaN     NaN     NaN      NaN
# 1131     NaN                      NaN  NaN     NaN     NaN      NaN
# 1132     1.0   Thantis, the Warweaver  C18  Mythic     NaN      NaN
# 1133     1.0           Lord Windgrace  C18  Mythic     NaN      NaN
# 1134     1.0  Gyrus, Waker of Corpses  C18  Mythic     NaN      NaN
#
# [1135 rows x 6 columns]

# %%
df['Card'].unique()
# Out:
# array(['Stoneforge Mystic', 'Breeding Pool', 'Aether Vial', ...,
#        'Thantis, the Warweaver', 'Lord Windgrace',
#        'Gyrus, Waker of Corpses'], dtype=object)

# %%
df = df.sort_values(by=['Card'])

# %%
df
# Out:
#       Amount                           Card  Set    Rarity   Value    Total
# 816      5.0             Abnormal Endurance  M19    Common   $0.25    $1.25
# 92       4.0                         Absorb  RNA      Rare   $1.00    $4.00
# 815      5.0                  Academy Drake  DOM    Common   $0.20    $1.00
# 855      2.0            Academy Journeymage  DOM    Common   $0.21    $0.42
# 874     17.0                 Act of Treason  RNA    Common   $0.20    $3.40
# 696      4.0                   Adamant Will  DOM    Common   $0.23    $0.92
# 926      4.0               Adaptive Snapjaw  GTC    Common   $0.19    $0.76
# 694      3.0            Adventurous Impulse  DOM    Common   $0.24    $0.72
# 536      2.0                Aerial Engineer  M19  Uncommon   $0.25    $0.50
# 959      1.0                Aerial Maneuver  GTC    Common   $0.19    $0.19
# 888     10.0                   Aeromunculus  RNA    Common   $0.20    $2.00
# ...
